# %% [markdown]
# # Find Functional Microniches
#
# This page is a **placeholder** tutorial. A full walkthrough will be added in a future release.
#
# ## What you will learn
#
# - How to run SpaceTravLR to characterize functional microniches in spatial transcriptomics data
# - How to interpret outputs and relate them to biological hypotheses

# %%
# Replace this cell with your SpaceTravLR workflow.
print("Placeholder: add CLI or Python API steps here.")
