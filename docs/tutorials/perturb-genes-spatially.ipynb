# %% [markdown]
# # Perturb Genes Spatially
#
# This page is a **placeholder** tutorial. A full walkthrough will be added in a future release.
#
# ## What you will learn
#
# - How to set up in-silico spatial gene perturbation experiments
# - How to compare perturbed versus baseline microniche structure

# %%
# Replace this cell with your SpaceTravLR spatial perturbation workflow.
print("Placeholder: add perturbation and visualization steps here.")
